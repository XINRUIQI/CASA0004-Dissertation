# %% [markdown]
# ### Dataset Overview

# %% [markdown]
# **1) Market & Financial Data**
#
# **1) Market & Financial & Oil Fundamentals Data**
#
# 1A. Target oil price
# - EIA Europe Brent Spot Price FOB
#
# 1B. Benchmark comparison
# - EIA Cushing, OK WTI Spot Price FOB
#
# 1C. U.S. petroleum fundamentals
# - EIA Weekly Petroleum Status Report
#   - commercial crude stocks
#   - Cushing crude stocks
#   - crude production
#   - crude imports / exports
#   - refinery inputs
#   - refinery utilisation
#   - gasoline product supplied
#   - distillate product supplied
#   - jet fuel product supplied
#
# 1D. Macro-financial control variables
# - FRED Nominal Broad U.S. Dollar Index
# - FRED Effective Federal Funds Rate / DFF
# - FRED 10-Year Treasury Yield / DGS10
# - FRED / CBOE VIX
# - Yahoo Finance S&P 500 (^GSPC)
#
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | EIA Europe Brent Spot Price FOB | Official EIA daily Europe Brent spot price, FOB basis | [EIA](https://www.eia.gov/dnav/pet/hist/rbrted.htm) | Daily spot price (USD per barrel) | May 1987–present | Daily / business days | Europe Brent; global crude oil benchmark| Price data | Open | Construct daily returns, rolling volatility, next-week cumulative return direction, realised volatility targets | Single price series; no intraday granularity; does not capture shipping activity, inventories, macro shocks or intraday market microstructure|
# | EIA Cushing, OK WTI Spot Price FOB | Official EIA daily WTI spot price at Cushing, Oklahoma | [EIA](https://www.eia.gov/dnav/pet/hist/RWTCD.htm) | WTI spot price, USD per barrel | 1986–present | Daily / business days | Cushing, Oklahoma, United States | Price data | Open | Construct WTI daily returns, rolling volatility, price direction labels, and WTI–Brent spread variables | WTI-specific benchmark; does not directly represent Brent or global crude prices; no intraday granularity; affected by US storage and logistics conditions |
# | EIA Weekly Petroleum Status Report | US petroleum inventories, refinery runs, imports/exports | [EIA](https://www.eia.gov/petroleum/supply/weekly/) | Inventory, refinery runs, imports, exports, production | 1980s/1990s -- present, depending on series | Weekly | United States | Market data | Open | Inventory pressure, refinery utilisation controls, structure-informed constraints | US-only; weekly frequency may lag or smooth daily price movements|
# | Macro-financial Control Variables | Daily financial indicators used to control for exchange-rate effects, monetary conditions, financial uncertainty and risk appetite | [FRED DTWEXBGS](https://fred.stlouisfed.org/series/DTWEXBGS); [FRED DFF](https://fred.stlouisfed.org/series/DFF); [FRED DGS10](https://fred.stlouisfed.org/series/DGS10); [FRED VIXCLS](https://fred.stlouisfed.org/series/VIXCLS); [Yahoo ^GSPC](https://finance.yahoo.com/quote/%5EGSPC/) | U.S. dollar index, effective federal funds rate, 10-year Treasury yield, VIX, S&P 500 | Varies by series; S&P 500 from Yahoo Finance covers full 2006–2025 study period | Daily / business days; aggregate to weekly | U.S. financial markets; used as global macro-financial proxies | Macro-financial control data | Open | Control for USD strength, interest rates, market uncertainty and risk appetite when forecasting Brent weekly returns, direction or volatility | Not oil-specific; mostly U.S.-based proxies; not direct measures of global oil supply-demand; must be aggregated to weekly frequency |
# | ❌暂时删掉，月度EIA Short-Term Energy Outlook (STEO) | US government short-term energy outlook with supply/demand forecasts | [EIA](https://www.eia.gov/outlooks/steo/) | Price forecasts, global supply/demand, inventories,trade, consumption, production, OPEC/non-OPEC supply, Brent/WTI prices | Updated monthly | Monthly | U.S. and Global | Market data + Report | Open | Regime/context features, supply/demand baseline expectations | Monthly frequency; may miss short-term shocks;forecast values may be revised each month |
# | ❌需要付费订阅ICE Brent Crude Futures | Futures settlement prices for Brent crude | [ICE](https://www.ice.com/futures-europe/market-resources) | Settlement, volume, OI, contract expiry | Varies by subscription | Daily | Global (ICE Europe) | Price data | Commercial (subscription reCquired) | Build term-structure, contango/backwardation, basis, and roll features | Historical EOD data requires paid subscription; not freely reproducible |
# | ❌需要付费订阅CME Brent Quotes & Settlements | Delayed quotes, daily settlements, OHLC | [CME](https://www.cmegroup.com/market-data/daily-settlements.html) | OHLC, settlement, volume, OI, margins | Varies | Daily | Global (CME) | Price data | Partial open (delayed) | Alternative futures proxy if ICE unavailable; spread and momentum features | Only delayed data is free; historical depth limited |
# OPEC Monthly Oil Market Report 不是 weekly
# IEA Oil Market Report 不是 weekly
#
#
# **1C. U.S. petroleum fundamentals**
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---|---|---|---|---|---|---|---|---|---|---|
# | EIA Weekly Commercial Crude Oil Stocks excluding SPR | Weekly US commercial crude oil inventories excluding the Strategic Petroleum Reserve | [EIA](https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?f=W&n=PET&s=WCESTUS1) | Commercial crude oil ending stocks excluding SPR | 1982 -- present | Weekly | United States | Market data / inventory data | Open | Measures inventory pressure and stock builds/draws; useful as a core market-fundamental feature for Brent/WTI forecasting | US-only; inventory data may not fully represent global crude balance; weekly frequency may lag or smooth daily price movements |
# | EIA Weekly US Field Production of Crude Oil | Weekly estimates of US domestic crude oil production | [EIA](https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?f=W&n=PET&s=WCRFPUS2) | US crude oil field production | 1980s/1990s -- present, depending on series | Weekly | United States | Market data / supply data | Open | Captures domestic supply conditions; useful as a supply-side control variable in oil price forecasting | US-only; production values are estimates and may be revised; does not capture OPEC or other non-US supply directly |
# | EIA Weekly US Imports of Crude Oil | Weekly US crude oil import volumes | [EIA](https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?f=W&n=PET&s=WCRIMUS2) | Crude oil imports | 1980s/1990s -- present, depending on series | Weekly | United States | Market data / trade data | Open | Captures inbound crude trade and import dependence; useful for modelling refinery feedstock supply and trade-related market pressure | US-only; affected by shipping delays, refinery maintenance and reporting timing; does not capture global crude trade flows |
# | EIA Weekly US Exports of Crude Oil | Weekly US crude oil export volumes | [EIA](https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?f=W&n=PET&s=WCREXUS2) | Crude oil exports | 1990s -- present, depending on series | Weekly | United States | Market data / trade data | Open | Captures outbound crude trade and external demand for US crude; useful for modelling trade-related pressure on crude balances | US-only; export volumes may be affected by infrastructure, policy and port constraints; weekly data may lag real-time shipping signals |
# | EIA Weekly US Refiner Net Input of Crude Oil | Weekly crude oil input into US refineries | [EIA](https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?f=W&n=PET&s=WCRRIUS2) | Refiner net input of crude oil | 1982 -- present | Weekly | United States | Market data / refinery activity data | Open | Measures refinery crude demand; useful for controlling refinery runs, seasonal maintenance and crude processing activity | US-only; affected by refinery outages, maintenance and seasonal cycles; does not directly measure final consumer demand |
# | EIA Weekly US Percent Utilization of Refinery Operable Capacity | Weekly percentage of US refinery operable capacity being used | [EIA](https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?f=W&n=PET&s=WPULEUS3) | Refinery capacity utilisation | 1990s -- present, depending on series | Weekly | United States | Market data / refinery utilisation data | Open | Captures refinery operating intensity; useful as a control for crude input, inventory movements and seasonal refinery activity | US-only; capacity utilisation can be affected by maintenance, weather disruptions and regional refinery constraints |
# | EIA Weekly Product Supplied of Finished Motor Gasoline | Weekly supplied volume of finished motor gasoline, commonly used as a proxy for gasoline demand | [EIA](https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?f=W&n=PET&s=wgfupus2) | Finished motor gasoline product supplied | 1990s -- present, depending on series | Weekly | United States | Market data / demand proxy | Open | Captures road transport fuel demand and seasonal driving patterns; useful as a demand-side feature | Product supplied is an implied demand proxy rather than direct consumer sales; US-only; affected by stock changes and reporting conventions |
# | EIA Weekly Product Supplied of Distillate Fuel Oil | Weekly supplied volume of distillate fuel oil, including diesel and heating oil | [EIA](https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?f=W&n=PET&s=WDIUPUS2) | Distillate fuel oil product supplied | 1990s -- present, depending on series | Weekly | United States | Market data / demand proxy | Open | Captures freight, industrial and heating-related demand; useful for modelling broader macro-demand pressure | Product supplied is an implied demand proxy; strong seasonality; US-only and not a direct measure of global diesel demand |
# | EIA Weekly Product Supplied of Kerosene-Type Jet Fuel | Weekly supplied volume of kerosene-type jet fuel, commonly used as a proxy for aviation fuel demand | [EIA](https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?f=W&n=PET&s=WKJUPUS2) | Kerosene-type jet fuel product supplied | 1990s -- present, depending on series | Weekly | United States | Market data / demand proxy | Open | Captures aviation-related fuel demand; useful for identifying travel-demand shocks and recovery periods | Product supplied is an implied demand proxy; US-only; aviation demand may be affected by exceptional shocks and seasonal travel patterns |
# | EIA Weekly Cushing, Oklahoma Crude Oil Stocks | Weekly crude oil stocks held at Cushing, Oklahoma, the delivery hub for WTI futures | [EIA](https://www.eia.gov/dnav/pet/hist/LeafHandler.ashx?f=W&n=PET&s=W_EPC0_SAX_YCUOK_MBBL) | Cushing, Oklahoma ending stocks of crude oil | 2004 -- present | Weekly | Cushing, Oklahoma, United States | Market data / inventory data | Open | Captures local storage pressure at the WTI delivery hub; especially useful for WTI price forecasting and WTI-Brent spread analysis | Location-specific; more relevant to WTI than Brent; may not represent broader US or global inventory conditions; weekly frequency may lag or smooth daily price movements |
#
# **1D. Macro-financial control variables**
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---|---|---|---|---|---|---|---|---|---|---|
# | FRED Nominal Broad U.S. Dollar Index | Daily U.S. dollar index used to control for exchange-rate effects in USD-denominated oil prices | [FRED DTWEXBGS](https://fred.stlouisfed.org/series/DTWEXBGS) | Nominal Broad U.S. Dollar Index | Jan 2006–present | Daily / business days; aggregate to weekly | U.S. financial market; global currency proxy | Macro-financial control data | Open | Control for U.S. dollar strength when forecasting Brent weekly returns, direction or volatility | Not oil-specific; not a direct measure of global oil supply-demand; not originally weekly |
# | FRED Effective Federal Funds Rate | Daily effective federal funds rate used to control for short-term U.S. monetary policy and liquidity conditions | [FRED DFF](https://fred.stlouisfed.org/series/DFF) | Effective federal funds rate, percent | Jul 1954–present | Daily; aggregate to weekly | U.S. financial market; global financial-condition proxy | Interest rate data / macro-financial control data | Open | Control for short-term interest rates, monetary policy and dollar liquidity conditions | U.S.-specific; slow-moving variable; not oil-specific; not a direct oil-market fundamental |
# | FRED 10-Year Treasury Constant Maturity Rate | Daily 10-year U.S. Treasury yield used to capture long-term rates and macro-financial expectations | [FRED DGS10](https://fred.stlouisfed.org/series/DGS10) | 10-year Treasury yield, percent | Jan 1962–present | Daily / business days; aggregate to weekly | U.S. bond market; global financial-condition proxy | Interest rate data / bond market data | Open | Control for long-term interest rates, inflation expectations and macro-financial sentiment | U.S.-specific; missing observations on holidays; not oil-specific; not originally weekly |
# | FRED / CBOE Volatility Index: VIX | Daily VIX close used to measure financial uncertainty and risk-off sentiment | [FRED VIXCLS](https://fred.stlouisfed.org/series/VIXCLS); [CBOE VIX Historical Data](https://www.cboe.com/tradable_products/vix/vix_historical_data/) | VIX close | Jan 1990–present | Daily close; aggregate to weekly | U.S. equity options market; global risk-sentiment proxy | Financial uncertainty / volatility index | Open | Control for market stress, uncertainty and risk-off sentiment that may affect oil price movements | U.S. equity-market proxy; not oil-specific; weekly mean, weekly max and Friday close may capture different meanings |
# | Yahoo Finance S&P 500 (^GSPC) | Daily S&P 500 index close used to capture equity-market sentiment and risk appetite | [Yahoo Finance ^GSPC](https://finance.yahoo.com/quote/%5EGSPC/) | S&P 500 close; weekly return | Jan 2006–Dec 2025 (full study period) | Daily close; aggregate to weekly | U.S. equity market; global risk-appetite proxy | Equity market index data | Open | Control for broader risk appetite and equity-market sentiment; construct weekly equity returns | U.S.-specific; not oil-specific; use weekly returns rather than raw index level |

# %% [markdown]
# **2) Official Reports & Structured Market Text**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | OPEC Monthly Oil Market Report (MOMR) | OPEC official monthly supply/demand, production, market balance report, prices, inventories, refinery activity, market balance, forecasts/revisions | [OPEC](https://www.opec.org/monthly-oil-market-report.html) | Supply/demand narratives, production data, market judgements | 2001 -- present | Monthly | Global (OPEC focus) | Report (PDF/text) | Open access; PDF download; parsing required| LLM-based extraction of monthly market narratives: supply shocks, demand revisions, production changes, refinery/tanker constraints, inventory signals, disruption risk, and market sentiment | Monthly only; OPEC-centric framing; PDF parsing required |
# | OPEC Annual Statistical Bulletin (ASB) | Long-term structural data on reserves, production, refining, trade, oil demand、prices、transportation、natural gas、macro-economics | [OPEC](https://www.opec.org/annual-statistical-bulletin.html) | Reserves, production, refining capacity, trade flows, tanker freight rates、oil prices、natural gas、petroleum exports | Historical, annual updates | Annual | Global, with detailed OPEC member coverage | Report (PDF/tabular) | Open | Supply-chain graph node weights, long-term structural context | Annual; not useful for daily/weekly features directly |
# | EIA STEO Report Text | Narrative commentary on Brent outlook, global liquid fuels, disruptions,inventories、OPEC+ production、gasoline/diesel、natural gas/LNG | [EIA](https://www.eia.gov/outlooks/steo/outlook.php) | Market commentary, Brent outlook narratives | Updated monthly | Monthly |global energy/oil markets, with strong U.S. focus | Report (PDF) | Open | Text-derived sentiment/event features, regime labels;forecast assumptions change; must align by release date | Monthly; narrative overlaps with STEO tables, but tabular data are not used directly |

# %% [markdown]
# **3) News, Company Announcements & Event Data**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | GDELT Event Database | Global event database: exogenous disruptions, conflicts, sanctions, accidents | [GDELT](https://www.gdeltproject.org/data.html) | Event codes (CAMEO), actors, locations, tones, timestamps | 1979 -- present | Sub-daily (15-min) | Global | Event data (tabular) | Open | Exogenous shock dummies, conflict intensity, transport disruption signals | Noisy; requires careful event-type filtering; may need ethics review for sensitive content |
# ❌BP 新闻稿网页公开可读，但 Python 自动访问被拒绝，所以不适合作为核心可下载数据，只能作为备用的公司新闻文本来源。| BP Press Releases | BP official press releases: shutdowns, maintenance, accidents, projects | [BP](https://www.bp.com/en/global/corporate/news-and-insights/press-releases.html) | Press release text, date, topic, region | 2010 -- present | Irregular | Global (BP operations) | Text (HTML) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; irregular timing |
# | Shell News & Media Releases | Shell media releases: quarterly results, operational updates | [Shell](https://www.shell.com/news-and-insights/newsroom/news-and-media-releases.html) | Press release text, date, category | 2013 -- present | Irregular | Global (Shell operations) | Text (HTML) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; irregular timing |
# | TotalEnergies News & Publications | TotalEnergies press releases, results, publications | [TotalEnergies](https://totalenergies.com/news) | Press release text, date, content type | Various | Irregular | Global (TotalEnergies) | Text (HTML/PDF) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; irregular timing |
# | Aramco News & Media | Saudi Aramco announcements, press releases, financial reports | [Aramco](https://www.aramco.com/en/news-media) | News text, reports, date | Various | Irregular | Global (Aramco) | Text (HTML/PDF) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; may involve data sensitivity |

# %% [markdown]
# **3) News, Company Announcements & Event Data**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | GDELT Event Database | Global machine-coded event database for conflict, sanction and disruption-related events | [GDELT](https://www.gdeltproject.org/data.html) | CAMEO event codes, actors, locations, Goldstein Scale, tone, timestamps, source URLs | 1979–present overall; GDELT 2.0 from Feb 2015–present | 15-min for GDELT 2.0 | Global | Event data (tabular) | Open | Exogenous disruption, conflict/sanction intensity and transport-disruption proxy indicators for oil-price forecasting | Noisy machine-coded data; requires careful filtering and ethical reflection |
# | Shell News & Media Releases | Shell media releases: quarterly results, operational updates | [Shell](https://www.shell.com/news-and-insights/newsroom/news-and-media-releases.html) | Press release text, date, category | 2013 -- present | Irregular | Global (Shell operations) | Text (HTML) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; irregular timing |
# | TotalEnergies News & Publications | TotalEnergies press releases, results, publications | [TotalEnergies](https://totalenergies.com/news) | Press release text, date, content type | Various | Irregular | Global (TotalEnergies) | Text (HTML/PDF) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; irregular timing |
# | Aramco News & Media | Saudi Aramco announcements, press releases, financial reports | [Aramco](https://www.aramco.com/en/news-media) | News text, reports, date | Various | Irregular | Global (Aramco) | Text (HTML/PDF) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; may involve data sensitivity |

# %% [markdown]
# **4) Remote Sensing (Optical / Night Lights)**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | Sentinel-2 (Copernicus) | Multispectral optical satellite imagery used to observe visible changes around selected ports, tank farms, oil terminals and refineries | [Copernicus](https://dataspace.copernicus.eu/data-collections/copernicus-sentinel-missions/sentinel-2) / [Google Earth Engine](https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR_HARMONIZED) | 13 spectral bands; 10m--60m spatial resolution; derived indicators such as NDVI, NDWI, NDBI, BSI and cloud-free observation count | 2015--present; Level-2A surface reflectance indicators used from 2017--2025 | 5-day revisit; aggregated to monthly indicators and aligned to weekly oil-price data | Global | Remote sensing imagery / derived tabular indicators | Open | Remote-sensing proxy for visible oil-infrastructure activity, construction, disruption and land-surface change around selected oil-related sites; used only in the 2017--2025 remote-sensing-enhanced experiment | Cloud cover reduces usable observations; 10m resolution is limited for vessel-level or tank-level detection; does not directly measure oil flow, storage volume or price; shorter availability than the full 2005--2025 study period |
# | Landsat Collection 2 Level-2 | Long-history surface reflectance and land surface temperature products from Landsat 4–9 | [USGS](https://www.usgs.gov/landsat-missions/landsat-collection-2-level-2-science-products) / [Google Earth Engine](https://developers.google.com/earth-engine/datasets/catalog/landsat) | Surface reflectance bands, QA masks, land surface temperature, derived indices such as NDVI, NDBI, BSI and NDWI | 1982 -- present; practically useful for this project from 2005 -- present | 16-day revisit | Global | Remote sensing (optical + thermal) | Open | Historical baseline for industrial site monitoring before Sentinel-2; monthly indicators of land-cover change, construction disturbance and thermal activity around oil-related infrastructure; cross-validation with Sentinel-2 after 2017 | 30 m resolution is coarser than Sentinel-2; 16-day revisit limits short-term event detection; cloud contamination and Landsat 7 SLC-off gaps require QA masking and monthly compositing |
# | NASA Black Marble / VIIRS Night Lights | NASA VIIRS nighttime lights products capturing corrected night-time radiance from human and industrial activity | [NASA](https://www.earthdata.nasa.gov/data/projects/black-marble) | Corrected nighttime radiance (nW/cm²/sr), quality flags, cloud/snow masks | 2012 -- present | Daily / Monthly / Annual | Global, ~500m | Remote sensing (night lights) | Open | Proxy for refinery, port, oil-storage and gas-flaring activity; construct monthly industrial activity indicators and anomalies for oil-market forecasting | Night lights are indirect proxies, not production data; affected by cloud/snow/moonlight, flaring, urban light spillover and spatial bleed; requires AOI buffering and quality control |

# %% [markdown]
# **5) Shipping & Port Activity**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | EMODnet Vessel Density | Monthly vessel-density raster maps for European waters, separated by ship type including Tanker | EMODnet Human Activities (https://ows.emodnet-humanactivities.eu/geonetwork/srv/api/records/0f2f3ff1-30ef-49e1-96e7-8ca78d58a07c) | Vessel density in 1 km × 1 km cells, expressed as hours/km²/month | 2017–2024 | Monthly / annual average | EU waters and neighbouring areas | Shipping / AIS-derived raster | Open, CC-BY 4.0 | Monthly tanker activity proxy for European sea routes, e.g. North Sea, Mediterranean, Suez-Europe corridor | Europe-focused only; monthly resolution; 2024 data affected by reduced satellite AIS coverage after June |
# | NOAA AIS / Marine Cadastre AIS | US Coast Guard AIS broadcast point data hosted by NOAA Marine Cadastre | NOAA Marine Cadastre (https://coast.noaa.gov/htdata/CMSP/AISDataHandler/2024/) | Vessel positions, speed, MMSI, vessel type, timestamp | 2009–2025 | Daily / sub-daily | US coastal waters | AIS / shipping | Open | Tanker activity proxies around Gulf Coast energy ports, including tanker counts, speed, waiting proxy and density | US waters only; very large files; requires vessel-type filtering and spatial aggregation |
# | IMF PortWatch | Global port calls and chokepoint transits from AIS | [IMF PortWatch](https://portwatch.imf.org/) | Daily port activity, chokepoint transit counts, disruption events | 2019 -- present | Daily | Global (major ports + 6 chokepoints: Hormuz, Suez, Malacca, Panama, Cape, Bab el-Mandeb) | Shipping / port activity | Open (API + CSV download) | Core shipping proxy: daily chokepoint transit volume directly correlates with global oil supply flow; disruption detection | Data lag ~3-5 days; aggregated counts (no vessel-level detail) |
# | Global Fishing Watch (AIS Vessel Presence) | AIS-derived global vessel presence hours | [GFW](https://globalfishingwatch.org/our-apis/) | Vessel presence hours by grid cell, vessel type | 2012 -- near real-time | Daily (gridded) | Global | Shipping / AIS | Open (academic, API key required) | Filter non-fishing vessels for tanker presence; global coverage; R package `gfwr` available | Primarily designed for fishing; tanker filtering requires vessel identity lookup; API rate limits |
# | Global Fishing Watch (SAR Vessel Detections) | Sentinel-1 SAR-based vessel detections matched with AIS | [GFW SAR](https://globalfishingwatch.org/platform-update/2024-may-data-download-portal-new-dataset-released-featuring-vessel-detections-from-sentinel-1-sar/) | SAR detection coordinates, AIS match status, fishing score, timestamp | 2017 -- 5 days ago | Satellite pass dependent | Global | Remote sensing + AIS | Open (academic) | Detect vessels not broadcasting AIS ("dark ships"); supplement AIS coverage gaps | Detection dependent on satellite pass schedule; not all detections are tankers |
# | Piraeus AIS Dataset | Dense AIS records for port of Piraeus (Greece) | [PMC](https://pmc.ncbi.nlm.nih.gov/articles/PMC8749179/) | Vessel position, MMSI, timestamp (ms), speed, course, vessel type, weather | May 2017 -- Dec 2019 | Sub-second (~10,000 records/hour) | Piraeus, Greece (single port) | Shipping / AIS | Open | Method validation: demonstrate AIS-to-activity pipeline at single-port scale; Suez-Mediterranean route relevance | Single port only; 2.5-year window; limited global explanatory power for oil price prediction |
# | ShipRSImageNet | Large-scale fine-grained ship detection from optical remote sensing (50 categories) | [GitHub](https://github.com/zzndream/ShipRSImageNet) | Ship imagery (930x930px), HBB + OBB bounding boxes, polygon masks, 50 ship type labels (incl. Oil Tanker, Container Ship, Cargo, RoRo) | Static dataset (published 2021) | N/A | Various global locations (imagery-based) | Remote sensing + annotations | Open | Pre-train / fine-tune oil tanker detection model; demonstrate CV classification capability; 17,573 labelled instances | Static; NO timestamp; no geographic coordinates; cannot support time-series analysis |
# | OpenSARShip | Sentinel-1 SAR ship chips with AIS-matched vessel type | [GitHub](https://github.com/opensar/OpenSARShip) | SAR image chips (VV/VH), AIS messages (vessel type, length, width), XML metadata | Static dataset | N/A | 5 major Asian ports | Remote sensing (SAR) + AIS | Open | SAR-based tanker classification (399 oil tanker instances); bridge between SAR imagery and vessel identity | Class imbalance (61% cargo); low resolution (20m/pixel); limited to 5 ports |
# | FGSCR-42 | Fine-grained ship classification in remote sensing (42 categories) | [GitHub](https://github.com/DYH666/FGSCR-42) | Ship images from Google Earth + public RS datasets, 42 categories (incl. Cargo Ship, Container Ship) | Images from past 20 years of 40 ports | N/A | 40 ports worldwide | Remote sensing (optical) | Open (Baidu download) | Alternative to ShipRSImageNet for ship classification; records capture time and geographic coordinates of source imagery | Capture time used for deduplication only (not per-image annotation); Baidu download may be slow outside China |
# | VENμS Vessel Detection (Zenodo) | Multispectral satellite images of Ashdod port with AIS annotations | [Zenodo](https://zenodo.org/records/14174195) | 12-band multispectral images (5.3m resolution), boundary boxes, AIS data (vessel type, length, width, status) | Jan 2018 -- Oct 2020 | ~2-day revisit (284 images) | Ashdod, Israel (single port) | Remote sensing (multispectral) + AIS | Open | Proof-of-concept: satellite imagery WITH timestamps AND AIS vessel-type labels; temporal coverage enables activity time series at port scale | Single port; small dataset (284 images); limited to Israeli waters |

# %% [markdown]
# **6) Supply-Chain Spatial Nodes & Network**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | World Port Index (WPI) | Static global database of maritime ports, including port locations, physical characteristics, facilities, services, and oil/LNG terminal indicators | [NGA](https://msi.nga.mil/Publications/WPI) | Port ID, port name, country, lat/lon, water body, harbour type/size, entrance/channel/anchorage/cargo pier depth, facilities, services, oil terminal flag, LNG terminal flag | Latest available static release; updated periodically/monthly by NGA | Static | Global / worldwide maritime ports (~3,700 ports) | Geospatial point data + tabular attributes (CSV; also available via WPI web application formats such as GeoPackage, JSON, Shapefile, File Geodatabase) | Open | Define port and oil/LNG terminal infrastructure nodes; support spatial matching with AIS, PortWatch, vessel-density data, chokepoints, and oil supply-chain graph construction | Static infrastructure snapshot only; no daily/weekly vessel activity, congestion, disruption, or trade-volume signal; requires linkage with dynamic shipping/port datasets for forecasting |
# | OGIM: Oil & Gas Infrastructure Mapping | Global oil and gas infrastructure mapping dataset, including refineries, petroleum terminals, LNG facilities, offshore platforms, gathering and processing facilities, tank batteries, pipelines and wells | [GEE](https://developers.google.com/earth-engine/datasets/catalog/EDF_OGIM_current) | OGIM_ID, FAC_NAME, CATEGORY, FAC_TYPE, COUNTRY, STATE_PROV, OPERATOR, OGIM_STATUS, FAC_STATUS, SRC_DATE, lat/lon | Current / near-current snapshot, GEE version timestamp 2024-05-15 | Periodically updated | Global | Geospatial FeatureCollection / table | Open via Google Earth Engine | Build static oil and gas infrastructure node layers; identify refinery, terminal, storage and processing AOIs; provide spatial anchors for VIIRS, Landsat, Sentinel, AIS/PortWatch and news-derived time-series indicators | Static infrastructure snapshot rather than continuous historical panel; many wells and pipelines require filtering; facility presence does not equal activity, capacity or production level |
# | Global Oil and Gas Extraction Tracker (GOGET) | Global oil and gas extraction project tracker covering oil and gas fields from discovery to decommissioning, including location, ownership, production, reserves, fuel type, and project status | [GEM](https://globalenergymonitor.org/projects/global-oil-gas-extraction-tracker/) | Field/project name, country, basin, coordinates, operator, ownership, status, fuel type, production, reserves, discovery/development/operation information | Current tracker; latest available download around Mar 2026 | Static / periodically updated | Global, 95 countries | Geospatial + tabular asset-level data | Open access via GEM download page | Upstream supply-side background features; construct oil/gas field nodes, active extraction counts, regional production/reserve weights, new field approval or discovery indicators, and supply-region node weights for graph-based oil market modelling | Not a daily time-series dataset; better suited to quarterly or annual features; may require cleaning, status filtering, and aggregation before merging with oil price data |
# | Global Oil Infrastructure Tracker (GOIT) | Global oil and NGL transmission pipeline infrastructure from Global Energy Monitor | [GEM](https://globalenergymonitor.org/projects/global-oil-infrastructure-tracker) | Pipeline name, route geometry, status, country/region, owner/operator, length, capacity where available, start year | Updated annually; latest visible download Mar 2025 | Static / annual | Global | Tabular + GIS line data | Open | Build midstream pipeline edges in the oil supply-chain graph; derive regional pipeline capacity, pipeline exposure, and alternative-route indicators | Not daily flow data; annual/static infrastructure snapshot; capacity and operating status may be incomplete for some pipelines |
# | EIA World Oil Transit Chokepoints | Reference data and explanatory material on major global oil maritime chokepoints | [EIA](https://www.eia.gov/international/analysis/special-topics/World_Oil_Transit_Chokepoints) | Chokepoint name, location, oil transit volume, route importance, alternative-route constraints, disruption context | Periodically updated / topic-based | Annual / Event-based | Global major oil transit routes | Tabular / text / figure data | Open | Build oil chokepoint reference table; define transport bottleneck nodes/edges; construct exogenous shock dummies and weighted chokepoint risk index | Not a daily AIS flow dataset; updates are infrequent; some values require manual extraction from text/figures; best used with PortWatch, AIS, GDELT, or news data |

# %% [markdown]
# **7) Weather & Auxiliary**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | ERA5 Daily Statistics (Copernicus) | Global reanalysis weather data | [CDS](https://cds.climate.copernicus.eu/datasets/derived-era5-single-levels-daily-statistics) | Wind, waves, temperature, precipitation, pressure | 1940 -- present | Hourly / Daily | Global (0.25 deg grid) | Weather / reanalysis | Open (CDS registration) | Shipping condition controls, refinery disruption risk, extreme weather flags | Large data volume; requires spatial subsetting; CDS registration needed |
# | NOAA IBTrACS | Global tropical cyclone best-track archive | [NOAA](https://www.ncei.noaa.gov/products/international-best-track-archive) | Storm track, intensity, wind speed, pressure, landfall | 1842 -- present | 6-hourly (per storm) | Global (all ocean basins) | Weather / event data | Open | Hurricane/typhoon event dummies, path-based disruption impact variables | Sparse events; not all storms affect oil infrastructure; requires spatial matching |
