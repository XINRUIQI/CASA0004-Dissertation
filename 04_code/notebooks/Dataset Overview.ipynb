# %% [markdown]
# ### Dataset Overview

# %% [markdown]
# **1) Market & Financial Data**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | EIA Brent Spot Price FOB | Primary Brent daily spot price (FOB basis) | [EIA](https://www.eia.gov/dnav/pet/hist/rbrted.htm) | Daily spot price (USD/bbl) | 1987 -- present | Daily | Global (Brent benchmark) | Price data | Open | Construct daily returns, rolling volatility, next-week cumulative return direction, realised volatility targets | Single price series; no intraday granularity |
# | ICE Brent Crude Futures | Futures settlement prices for Brent crude | [ICE](https://www.ice.com/futures-europe/market-resources) | Settlement, volume, OI, contract expiry | Varies by subscription | Daily | Global (ICE Europe) | Price data | Commercial (subscription required) | Build term-structure, contango/backwardation, basis, and roll features | Historical EOD data requires paid subscription; not freely reproducible |
# | CME Brent Quotes & Settlements | Delayed quotes, daily settlements, OHLC | [CME](https://www.cmegroup.com/market-data/daily-settlements.html) | OHLC, settlement, volume, OI, margins | Varies | Daily | Global (CME) | Price data | Partial open (delayed) | Alternative futures proxy if ICE unavailable; spread and momentum features | Only delayed data is free; historical depth limited |
# | EIA Weekly Petroleum Status Report | US petroleum inventories, refinery runs, imports/exports | [EIA](https://www.eia.gov/dnav/pet/pet_pri_spt_s1_d.htm) | Inventory, refinery runs, imports, exports, production | 1990s -- present | Weekly | United States | Market data | Open | Inventory pressure, refinery utilisation controls, structure-informed constraints | US-only; weekly lag relative to daily inputs |
# | EIA Short-Term Energy Outlook (STEO) | US government short-term energy outlook with supply/demand forecasts | [EIA](https://www.eia.gov/outlooks/steo/) | Price forecasts, global supply/demand, inventories | Updated monthly | Monthly | Global | Market data + Report | Open | Regime/context features, supply/demand baseline expectations | Monthly frequency; may miss short-term shocks |
#
# **2) Official Reports & Structured Market Text**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | OPEC Monthly Oil Market Report (MOMR) | OPEC official monthly supply/demand, production, market balance report | [OPEC](https://www.opec.org/monthly-oil-market-report.html) | Supply/demand narratives, production data, market judgements | 2001 -- present | Monthly | Global (OPEC focus) | Report (PDF/text) | Open (may require registration) | LLM-based event extraction: supply/demand shifts, production quotas, market sentiment | Monthly only; OPEC-centric framing; PDF parsing required |
# | OPEC Annual Statistical Bulletin (ASB) | Long-term structural data on reserves, production, refining, trade | [OPEC](https://www.opec.org/) | Reserves, production, refining capacity, trade flows | Historical, annual updates | Annual | Global (OPEC members) | Report (PDF/tabular) | Open | Supply-chain graph node weights, long-term structural context | Annual; not useful for daily/weekly features directly |
# | EIA STEO Report Text | Narrative commentary on Brent outlook, global liquid fuels, disruptions | [EIA](https://www.eia.gov/outlooks/steo/report/global_oil.php) | Market commentary, Brent outlook narratives | Updated monthly | Monthly | Global | Report (HTML/PDF) | Open | Text-derived sentiment/event features, regime labels | Monthly; partly overlaps with STEO tabular data |
#
# **3) News, Company Announcements & Event Data**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | GDELT Event Database | Global event database: geopolitical disruptions, conflicts, sanctions, accidents | [GDELT](https://www.gdeltproject.org/data.html) | Event codes (CAMEO), actors, locations, tones, timestamps | 1979 -- present | Sub-daily (15-min) | Global | Event data (tabular) | Open | Geopolitical shock dummies, conflict intensity, transport disruption signals | Noisy; requires careful event-type filtering; may need ethics review for sensitive content |
# | BP Press Releases | BP official press releases: shutdowns, maintenance, accidents, projects | [BP](https://www.bp.com/en/global/corporate/news-and-insights/press-releases.html) | Press release text, date, topic, region | 2010 -- present | Irregular | Global (BP operations) | Text (HTML) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; irregular timing |
# | Shell News & Media Releases | Shell media releases: quarterly results, operational updates | [Shell](https://www.shell.com/news-and-insights/newsroom/news-and-media-releases.html) | Press release text, date, category | 2013 -- present | Irregular | Global (Shell operations) | Text (HTML) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; irregular timing |
# | TotalEnergies News & Publications | TotalEnergies press releases, results, publications | [TotalEnergies](https://totalenergies.com/news) | Press release text, date, content type | Various | Irregular | Global (TotalEnergies) | Text (HTML/PDF) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; irregular timing |
# | Aramco News & Media | Saudi Aramco announcements, press releases, financial reports | [Aramco](https://www.aramco.com/en/news-media) | News text, reports, date | Various | Irregular | Global (Aramco) | Text (HTML/PDF) | Open | Company-level supply shock signals via NLP extraction | Web scraping needed; single-company bias; may involve geopolitical sensitivity |
#
# **4) Remote Sensing (Optical / Night Lights)**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | Sentinel-2 (Copernicus) | Multispectral optical imagery of ports, tank farms, refineries | [Copernicus](https://dataspace.copernicus.eu/data-collections/copernicus-sentinel-missions/sentinel-2) | 13-band multispectral imagery (10m--60m) | 2015 -- present | 5-day revisit | Global | Remote sensing (optical) | Open | Visual proxies for port activity, storage-site change detection, refinery status | Cloud cover reduces usable observations; 5-day revisit may miss short events |
# | Landsat Collection 2 Level-2 | Long-history surface reflectance and temperature products | [USGS](https://www.usgs.gov/landsat-missions/landsat-collection-2-level-2-science-products) | Surface reflectance, surface temperature | 1982 -- present | 16-day revisit | Global | Remote sensing (optical) | Open | Extended temporal baseline for industrial site monitoring, cross-validation with Sentinel-2 | 16-day revisit too coarse for daily features; lower resolution than Sentinel-2 |
# | NASA Black Marble / VIIRS Night Lights | Daily/monthly/annual nighttime lights for industrial activity | [NASA](https://www.earthdata.nasa.gov/data/projects/black-marble) | Nighttime radiance (nW/cm2/sr) | 2012 -- present | Daily / Monthly / Annual | Global | Remote sensing (night lights) | Open | Refinery-related night-time lights proxy, industrial activity intensity | Cloud/moonlight interference; radiance does not equal production directly; spatial bleed |
#
# **5) Shipping & Port Activity**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | Kpler AIS / Historical AIS | Global vessel tracking, tanker density, shipping analytics | [Kpler](https://www.kpler.com/product/maritime/kplerais) | Vessel position, speed, draft, cargo, route | Multi-year historical | Sub-daily | Global | Shipping / AIS | Commercial (paid subscription) | Tanker density, port congestion, cargo flow features | Paid; not reproducible without licence; data agreement needed |
# | MarineTraffic Port Congestion | Port and terminal congestion indices from AIS | [MarineTraffic](https://support.marinetraffic.com/en/articles/9552791-port-congestion) | Port congestion index, terminal congestion, waiting time | Various | Weekly | Global (major ports) | Shipping / port activity | Commercial (paid subscription) | Direct port congestion proxy for midstream bottleneck features | Paid; weekly resolution may lag daily inputs |
# | Vortexa Cargo Tracking | Oil tanker cargo flows, floating storage, freight analytics | [Vortexa](https://www.vortexa.com/feature/energy-flow-analytics-cargo-tracking) | Cargo flows, freight rates, floating storage, origin/dest | Various | Daily | Global | Shipping / cargo flow | Commercial (paid subscription) | Waterborne crude flow, floating storage as inventory proxy | Paid; proprietary methodology; not reproducible |
# | AISHub | Free AIS data sharing with API access | [AISHub](https://www.aishub.net/) | Vessel position, MMSI, speed, course | Real-time + limited history | Real-time | Partial (contributor-based) | Shipping / AIS | Open | Lightweight tanker density alternative; method validation | Sparse coverage; no guaranteed historical depth |
# | EMODnet Vessel Density | Gridded vessel/tanker density for European waters | [EMODnet](https://emodnet.ec.europa.eu/) | Vessel density rasters by ship type (tankers) | 2017 -- present | Monthly / Annual | EU & adjacent seas | Shipping / geospatial raster | Open | Regional tanker density proxy for North Sea / Mediterranean routes | EU-only; monthly aggregation too coarse for daily features |
# | NOAA AIS Data (US Waters) | US Coast Guard AIS vessel positions archived by NOAA Marine Cadastre | [NOAA](https://coast.noaa.gov/htdata/CMSP/AISDataHandler/2024/) | Vessel position, MMSI, speed, course, heading, vessel type, timestamp | 2009 -- 2025 | Daily (per-second records) | United States (all waters) | Shipping / AIS | Open | Filter by tanker vessel type to build daily oil tanker activity time series; Houston/Gulf of Mexico coverage for global refining hub | Large file sizes (~81 GB/year); US-only coverage; requires vessel-type filtering |
# | IMF PortWatch | Global port calls and chokepoint transits from AIS | [IMF PortWatch](https://portwatch.imf.org/) | Daily port activity, chokepoint transit counts, disruption events | 2019 -- present | Daily | Global (major ports + 6 chokepoints: Hormuz, Suez, Malacca, Panama, Cape, Bab el-Mandeb) | Shipping / port activity | Open (API + CSV download) | Core shipping proxy: daily chokepoint transit volume directly correlates with global oil supply flow; disruption detection | Data lag ~3-5 days; aggregated counts (no vessel-level detail) |
# | Global Fishing Watch (AIS Vessel Presence) | AIS-derived global vessel presence hours | [GFW](https://globalfishingwatch.org/our-apis/) | Vessel presence hours by grid cell, vessel type | 2012 -- near real-time | Daily (gridded) | Global | Shipping / AIS | Open (academic, API key required) | Filter non-fishing vessels for tanker presence; global coverage; R package `gfwr` available | Primarily designed for fishing; tanker filtering requires vessel identity lookup; API rate limits |
# | Global Fishing Watch (SAR Vessel Detections) | Sentinel-1 SAR-based vessel detections matched with AIS | [GFW SAR](https://globalfishingwatch.org/platform-update/2024-may-data-download-portal-new-dataset-released-featuring-vessel-detections-from-sentinel-1-sar/) | SAR detection coordinates, AIS match status, fishing score, timestamp | 2017 -- 5 days ago | Satellite pass dependent | Global | Remote sensing + AIS | Open (academic) | Detect vessels not broadcasting AIS ("dark ships"); supplement AIS coverage gaps | Detection dependent on satellite pass schedule; not all detections are tankers |
# | Piraeus AIS Dataset | Dense AIS records for port of Piraeus (Greece) | [PMC](https://pmc.ncbi.nlm.nih.gov/articles/PMC8749179/) | Vessel position, MMSI, timestamp (ms), speed, course, vessel type, weather | May 2017 -- Dec 2019 | Sub-second (~10,000 records/hour) | Piraeus, Greece (single port) | Shipping / AIS | Open | Method validation: demonstrate AIS-to-activity pipeline at single-port scale; Suez-Mediterranean route relevance | Single port only; 2.5-year window; limited global explanatory power for oil price prediction |
# | ShipRSImageNet | Large-scale fine-grained ship detection from optical remote sensing (50 categories) | [GitHub](https://github.com/zzndream/ShipRSImageNet) | Ship imagery (930x930px), HBB + OBB bounding boxes, polygon masks, 50 ship type labels (incl. Oil Tanker, Container Ship, Cargo, RoRo) | Static dataset (published 2021) | N/A | Various global locations (imagery-based) | Remote sensing + annotations | Open | Pre-train / fine-tune oil tanker detection model; demonstrate CV classification capability; 17,573 labelled instances | Static; NO timestamp; no geographic coordinates; cannot support time-series analysis |
# | OpenSARShip | Sentinel-1 SAR ship chips with AIS-matched vessel type | [GitHub](https://github.com/opensar/OpenSARShip) | SAR image chips (VV/VH), AIS messages (vessel type, length, width), XML metadata | Static dataset | N/A | 5 major Asian ports | Remote sensing (SAR) + AIS | Open | SAR-based tanker classification (399 oil tanker instances); bridge between SAR imagery and vessel identity | Class imbalance (61% cargo); low resolution (20m/pixel); limited to 5 ports |
# | FGSCR-42 | Fine-grained ship classification in remote sensing (42 categories) | [GitHub](https://github.com/DYH666/FGSCR-42) | Ship images from Google Earth + public RS datasets, 42 categories (incl. Cargo Ship, Container Ship) | Images from past 20 years of 40 ports | N/A | 40 ports worldwide | Remote sensing (optical) | Open (Baidu download) | Alternative to ShipRSImageNet for ship classification; records capture time and geographic coordinates of source imagery | Capture time used for deduplication only (not per-image annotation); Baidu download may be slow outside China |
# | VENμS Vessel Detection (Zenodo) | Multispectral satellite images of Ashdod port with AIS annotations | [Zenodo](https://zenodo.org/records/14174195) | 12-band multispectral images (5.3m resolution), boundary boxes, AIS data (vessel type, length, width, status) | Jan 2018 -- Oct 2020 | ~2-day revisit (284 images) | Ashdod, Israel (single port) | Remote sensing (multispectral) + AIS | Open | Proof-of-concept: satellite imagery WITH timestamps AND AIS vessel-type labels; temporal coverage enables activity time series at port scale | Single port; small dataset (284 images); limited to Israeli waters |
#
# **6) Supply-Chain Spatial Nodes & Network**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | World Port Index (WPI) | Global port and oil terminal locations with operational attributes | [NGA](https://msi.nga.mil/) | Port name, lat/lon, depth, facilities, services | Periodically updated | Static / Annual | Global (~3,700 ports) | Geospatial (point) | Open | Define port/terminal nodes in supply-chain graph | Static snapshot; no temporal activity signal |
# | OGIM: Oil & Gas Infrastructure Mapping | Global oil & gas infrastructure (terminals, processing, storage) | [GEE](https://developers.google.com/earth-engine/datasets/catalog/EDF_OGIM_current) | Facility type, location, status | Current snapshot | Periodic updates | Global | Geospatial (GEE) | Open | Identify storage, processing, terminal nodes for graph construction | Single snapshot; may miss facility changes |
# | Global Oil & Gas Extraction Tracker (GOGET) | Upstream oil/gas field and extraction unit tracking | [GEM](https://globalenergymonitor.org/projects/global-oil-gas-extraction-tracker/) | Unit name, status, location, capacity, operator | Current + historical | Quarterly | Global | Tabular / geospatial | Registration required (CC BY 4.0, free) | Production-region nodes, upstream capacity weights | Form submission needed; quarterly updates only |
# | Global Oil Infrastructure Tracker (GOIT) | Midstream crude oil and NGL pipeline tracking | [GEM](https://globalenergymonitor.org/projects/global-oil-infrastructure-tracker/) | Pipeline name, route, status, capacity, operator | Current + historical | Quarterly | Global | Tabular / GIS | Registration required (CC BY 4.0, free) | Pipeline edges in supply-chain graph, transport capacity constraints | Form submission needed; quarterly updates only |
# | EIA World Oil Transit Chokepoints | Key maritime chokepoints with flow volumes | [EIA](https://www.eia.gov/international/analysis/special-topics/World_Oil_Transit_Chokepoints) | Chokepoint name, location, transit volume (mb/d) | Updated periodically | Annual / Event-based | Global (major chokepoints) | Tabular / text | Open | Chokepoint nodes/edges in graph; shock dummy variables | Infrequent updates; aggregate annual volumes |
# | KAPSARC Refinery Capacity | Designed capacity of global oil refineries | [KAPSARC](https://datasource.kapsarc.org/explore/dataset/designed-capacity-of-oil-refineries/) | Refinery name, country, designed capacity (bbl/d) | Various years | Periodic updates | Global | Tabular | Partial (browsable; terms restrict commercial use) | Refinery node weights, downstream capacity constraints in graph | Terms restrict redistribution; no temporal change series |
#
# **7) Weather & Auxiliary**
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | ERA5 Daily Statistics (Copernicus) | Global reanalysis weather data | [CDS](https://cds.climate.copernicus.eu/datasets/derived-era5-single-levels-daily-statistics) | Wind, waves, temperature, precipitation, pressure | 1940 -- present | Hourly / Daily | Global (0.25 deg grid) | Weather / reanalysis | Open (CDS registration) | Shipping condition controls, refinery disruption risk, extreme weather flags | Large data volume; requires spatial subsetting; CDS registration needed |
# | NOAA IBTrACS | Global tropical cyclone best-track archive | [NOAA](https://www.ncei.noaa.gov/products/international-best-track-archive) | Storm track, intensity, wind speed, pressure, landfall | 1842 -- present | 6-hourly (per storm) | Global (all ocean basins) | Weather / event data | Open | Hurricane/typhoon event dummies, path-based disruption impact variables | Sparse events; not all storms affect oil infrastructure; requires spatial matching |
