# %% [markdown]
# ### Dataset Overview
#
# - Study period: **2006-01 – 2025-12**, aligned to **Friday-ending weekly frequency (W-FRI)**.
# - All sources are public and free; only Global Fishing Watch (M3) requires a free API token.

# %% [markdown]
# **M1) Core Market, Macro & Financial Variables**
#
# 10 variables covering oil-price own dynamics, supply fundamentals, global demand, precautionary demand, and market/financial conditions. All aligned to Friday-ending weekly frequency, January 2006 – December 2025.
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | EIA Europe Brent Spot Price FOB + Weekly Petroleum Status Report | Official EIA Brent crude spot price and US commercial crude oil inventories excluding the Strategic Petroleum Reserve | [EIA Brent](https://www.eia.gov/petroleum/gasdiesel/); [EIA WPSR](https://www.eia.gov/petroleum/supply/weekly/) | Brent spot price (USD/barrel); lagged prices and log returns; weekly inventory change (first difference of commercial crude stocks) | Jan 2006–Dec 2025 | Daily (price) and weekly (stocks); aggregated to weekly | Europe Brent benchmark; United States (inventories) | Price / inventory data | Open | Construct oil-price momentum and lag features, target variables (return, direction, volatility); measure inventory build/draw pressure as supply-demand balance proxy | US-only inventories; single price series; does not capture non-US storage or global crude balance |
# | Dallas Fed Index of Global Real Economic Activity | Kilian's index of global real economic activity based on dry cargo shipping rates, used as a proxy for global industrial commodity demand | [Dallas Fed](https://www.dallasfed.org/research/igrea) | Global real economic activity index | Feb 2006–Dec 2025 | Monthly; forward-filled and lagged to weekly to respect publication delay | Global | Macro activity index | Open | Proxy for aggregate global demand for industrial commodities, following the Kilian (2009) demand identification framework | Monthly frequency limits short-term responsiveness; publication lag of approximately five weeks |
# | FRED: IMF Industrial Materials Index, 10-Year Treasury, LBMA Gold, VIX | Macro-financial and cross-commodity indicators accessed via FRED | [PINDUINDEXM](https://fred.stlouisfed.org/series/PINDUINDEXM); [DGS10](https://fred.stlouisfed.org/series/DGS10); [GOLDPMGBD228NLBM](https://fred.stlouisfed.org/series/GOLDPMGBD228NLBM); [VIXCLS](https://fred.stlouisfed.org/series/VIXCLS) | Global price index of industrial materials; 10-year Treasury yield change (first difference); gold price log return; CBOE VIX close | Jan 2006–Dec 2025 (industrial materials from Feb 2006) | Daily (Treasury, gold, VIX) and monthly (industrial materials); aggregated to weekly | US financial markets and global commodity markets | Interest rate / commodity price / volatility index | Open | Control for non-oil industrial demand conditions, interest-rate changes and holding costs, cross-commodity risk linkage, and broad financial market uncertainty | US-centric proxies; VIX reflects equity-market rather than oil-specific uncertainty; monthly industrial materials index introduces publication lag |
# | Yahoo Finance: Brent Front-Month Futures, CBOE OVX, Commodity Currencies | Market-traded oil futures, oil-specific volatility index, and commodity-exporter exchange rates | [BZ=F](https://finance.yahoo.com/quote/BZ%3DF); [OVX](https://finance.yahoo.com/quote/%5EOVX); [CADUSD=X](https://finance.yahoo.com/quote/CADUSD=X) | Futures–spot log spread (Brent front-month minus Brent spot); CBOE Crude Oil Volatility Index (OVX); mean weekly percentage change of CAD/USD and AUD/USD | OVX from May 2007; futures from Aug 2007; FX from Jan 2006 | Daily; aggregated to weekly | Brent futures market; US options market; Canadian and Australian dollar | Futures / volatility / exchange rate | Open | Capture term-structure signals and backwardation; oil-specific uncertainty distinct from broad equity VIX; commodity-exporter FX channel as alternative to broad US dollar index | OVX and futures spread available only from 2007; commodity FX is a two-currency proxy rather than a comprehensive commodity-exporter basket |
# | Geopolitical Risk Index (GPR) | Monthly news-based index measuring geopolitical risk from newspaper articles, constructed by Caldara and Iacoviello (2022) | [GPR](https://www.matteoiacoviello.com/gpr.htm) | Geopolitical risk index (overall GPR) | Jan 2006–Dec 2025 | Monthly; forward-filled and lagged to weekly to respect publication delay | Global | News-text aggregate index | Open | Low-frequency proxy for precautionary oil-demand shifts driven by geopolitical tensions, conflict, and sanctions | Monthly frequency; text-based construction may not capture all geopolitical events equally; limited short-term variation |

# %% [markdown]
# **M2) Remote Sensing Variables**
#
# 44 features (4 indicator types × 11 oil-infrastructure AOIs), derived from satellite nighttime-light and daytime optical imagery. Three-layer design: dynamic nighttime-light activity anomalies, observation quality indicators, and daytime optical information availability. Covers 11 oil-infrastructure areas of interest (centre point + 5 km buffer), including major export terminals, import/refining hubs, and storage zones. All data obtained free via Google Earth Engine.
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | NOAA VIIRS Day/Night Band Monthly Composites | Monthly nighttime-light radiance composites capturing nocturnal radiance from industrial, port and oil-infrastructure activity; cloud-free observation count provides data-quality control | [Google Earth Engine](https://developers.google.com/earth-engine/datasets/catalog/NOAA_VIIRS_DNB_MONTHLY_V1_VCMSLCFG) | Nighttime-light anomaly (within-site expanding-window z-score of monthly mean radiance) per AOI; cloud-free observation count per AOI. 22 features total (11 anomaly + 11 quality) | Jan 2014–Dec 2025 | Monthly; forward-filled to weekly | 11 oil-infrastructure AOIs, ~500 m resolution, 5 km buffer | Remote sensing (night lights) | Open (Google Earth Engine) | Proxy for anomalous port, anchorage and oil-terminal activity relative to site-specific history; observation quality control for data completeness | Night lights are indirect proxies, not production or throughput data; weak correlation with oil-tanker traffic specifically; affected by urban light spillover, gas flaring and spatial bleed; requires within-site normalisation to be informative over time |
# | Copernicus Sentinel-2 Surface Reflectance + Cloud Probability | Multispectral daytime optical imagery and associated cloud probability used to measure optical observation availability around oil-infrastructure sites | [Google Earth Engine](https://developers.google.com/earth-engine/datasets/catalog/COPERNICUS_S2_SR_HARMONIZED) | Clear-sky observation count per AOI; cloud fraction (proportion of cloudy observations) per AOI. 22 features total (11 clear-obs + 11 cloud-fraction) | Apr 2017–Dec 2025 | Monthly; forward-filled to weekly | 11 oil-infrastructure AOIs, 10 m resolution, 5 km buffer | Remote sensing (optical) | Open (Google Earth Engine) | Proxy for satellite information availability around oil-storage and terminal sites; cloud fraction serves as an information-gap indicator that may relate to market uncertainty about physical inventories | Cloud cover reduces usable observations; 10 m resolution insufficient for vessel-level or individual-tank detection; shorter availability than the full 2006–2025 study period; does not directly measure oil flow, storage volume or price |

# %% [markdown]
# **M3) Shipping & Port Activity Variables**
#
# 119 candidate features derived from AIS-based maritime datasets, focused on tanker-specific indicators: transit flow intensity, deadweight-tonnage (DWT) capacity weighting, average vessel size, chokepoint-level disaggregation, export–import directional asymmetry, and congestion/dwell proxies. Covers 6 major oil-related maritime chokepoints (Strait of Hormuz, Suez Canal, Strait of Malacca, Bab el-Mandeb, Panama Canal, Cape of Good Hope) and 14 key oil-tanker port hubs.
#
# | Dataset | Summary | URL | Variables | Time Range | Frequency | Coverage | Data Type | Access | Potential Use | Limitations |
# |---------|---------|-----|-----------|------------|-----------|----------|-----------|--------|---------------|-------------|
# | IMF PortWatch (Chokepoint Transits + Port Activity) | AIS-derived daily vessel transits through maritime chokepoints by vessel type and capacity, plus port-level tanker import/export tonnage estimates at 14 major oil hubs | [IMF PortWatch](https://portwatch.imf.org/) | Chokepoint-level (6 chokepoints × 9 indicators): tanker transit count, tanker capacity, tanker share of total traffic, tanker capacity share, average tanker size, week-on-week change, 4-week moving average, total vessel count, total capacity; global aggregates. Port-level (7 indicators): export hub volume, import hub volume, net export–import balance, asymmetry ratio, log ratio, 4-week smoothed asymmetry, week-on-week export change. 64 features total | Jan 2019–Dec 2025 | Daily; aggregated to weekly sums | 6 maritime chokepoints (Hormuz, Suez, Malacca, Bab el-Mandeb, Panama, Cape) + 14 tanker hubs (9 export, 5 import/refining) | Shipping / port activity | Open (ArcGIS FeatureServer) | Tanker traffic-intensity proxy for seaborne crude oil flow; chokepoint disruption detection; directional export–import asymmetry reflecting loading vs unloading imbalances | Chokepoint transits are a coarse proxy, not exact oil trade volumes; chokepoint data does not distinguish transit direction; port tonnage estimated from AIS vessel draft rather than direct cargo measurement; data available only from 2019 |
# | Global Fishing Watch Vessel Presence (4Wings API) | AIS-derived monthly vessel-presence hours and vessel counts by type within chokepoint polygons, providing vessel dwell-time and congestion indicators | [GFW APIs](https://globalfishingwatch.org/our-apis/) | Per chokepoint (6 chokepoints × 9 indicators): total presence hours, total vessel count, cargo-vessel hours, bunker-vessel hours, other-vessel hours, non-tanker hours, other-vessel share, month-on-month change, dwell hours per vessel (congestion proxy); global aggregate. 55 features total | Jan 2012–Dec 2025 | Monthly; forward-filled to weekly | 6 chokepoint polygons | Shipping / AIS presence | Open (free API token required) | Congestion and dwell-time proxy based on average hours per vessel; longer historical coverage than PortWatch (from 2012); vessel-type breakdown for traffic composition analysis | Monthly granularity limits detection of short-term disruptions; no dedicated anchorage-waiting or queue-length data; vessel-type categories are broad and not purely oil-tanker specific; tanker filtering is approximate |
